# %%
import json
import torchaudio
from pathlib import Path
from copy import copy
from docx.api import Document
import soundfile as sf
import librosa
from pydub.utils import mediainfo
from tqdm.auto import tqdm
import pandas as pd

from data_utils import NeutuneSet

# %%
# dataset = NeutuneSet('/home/teo/userdata/nia_dataset/field_recording')
dataset = NeutuneSet('/home/teo/label-studio_files/nia_dataset/__DATA_v4')

# %%
dataset.wav_list
# Out:
# [PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-1-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-2-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-75-3-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-어상진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-이상화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-1-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-고수완.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-어상진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-2-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-어상진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-3-채강해.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-4-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-4-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-4-채강해.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-5-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-5-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-6-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-78-7-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-79-1-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-79-1-어상진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-79-2-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-79-2-김원준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-79-2-최용욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-79-3-최용욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-79-4-김동영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-79-5-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-79-8-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-80-1-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-80-2-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-80-2-김지호.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-80-2-이상화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-80-3-이상화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-1-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-2-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-3-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-4-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-86-4-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-1-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-2-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-가민지.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-김상연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-김수환.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-김양우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-김준형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-김효종.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-박한진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-송화영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-이동화.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-이주헌.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-3-장완석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-87-4-김승훈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-92-1-김근민.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-92-1-최용욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-92-2-김동영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-92-3 최용욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-92-3-김동영.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/fs-2-4-92-5-김원준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-1-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-10-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-11-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-12-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-13-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-14-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-15-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-2-허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-3-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-4-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-4-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-4-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-4-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-4-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-5-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-5-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-5-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-6-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-7-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-8-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-1-9-박채원.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-1-허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-10-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-11-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-12-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-13-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-2-허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3 허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-3-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-4-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-4-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-5-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-8-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-2-9-김민규.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-1-허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-10-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-11-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-12-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-13-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-14-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-15-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-2-허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-3-허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-4-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-4-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-4-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-5-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-5-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-6-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-6-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-7-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-8-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-3-9-손보광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-1-허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-10-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-11-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-12-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-13-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-14-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-2-허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-김시온.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-김영운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-김영은.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-김유찬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-민건욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-박영진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-서신웅.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-송영재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-위태진.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-윤상빈.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-이주석.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-이주용.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-전병준.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-전소형.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-정경운.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-정욱.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-조민우.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-천명재.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-한은광.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-3-허진만.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-4-구소연.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-4-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-5-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-6-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-7-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-8-백승렬.wav'),
#  PosixPath('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/wav/r-1-1-4-9-백승렬.wav')]

# %%
from pandas import read_table


class MetaCreator:
  def __init__(self, vocab_path):
    with open(vocab_path, 'r') as f:
      self.vocab = json.load(f)
    self.error_list = []

  def get_recording_type(self, wav_path):
    if '폴리' in wav_path:
      return '폴리'
    elif '합성' in wav_path:
      return '합성'
    elif '필드' in wav_path:
      return '필드 레코딩'

  def check_mp3_format(self, wav_path):
    mp3_path = wav_path.parent.parent / 'mp3' / wav_path.with_suffix('.mp3').name
    mp3_info = mediainfo(mp3_path)
    if int(mp3_info["sample_rate"]) != 48000:
        print(f"Error in MP3 SR: {mp3_path} is {mp3_info['sample_rate']}")
    if abs(int(mp3_info["bit_rate"]) - 320000) > 300 :
      print(f"Error in MP3 bit_rate: {mp3_path} is {mp3_info['bit_rate']}")
    return float(mp3_info["duration"])

  def check_name_is_wrong(self, wav_path):
    '''
    소분류 번호와 대분류/중분류 번호가 일치하는지 확인
    '''
    name = wav_path.stem
    high, middle, fine = [int(x) for x in name.split('-')[1:4]]
    voc = self.vocab[fine-1]
    assert voc["소분류_번호"] == fine
    if high != voc['대분류_번호']:
      print(f"Correct High: {voc['대분류_번호']} / Current High: {high} / Current Fine: {fine}")
      return True
    if middle != voc['중분류_번호']:
      print(f"Correct middle: {voc['중분류_번호']} / Current middle: {middle} / Current Fine: {fine}")

      return True
    return False

  def add_error(self, wav_path, error_str):
    self.error_list.append({'file': wav_path.name, 'error': error_str})

  def get_category_idx(self, wav_path):
    name = wav_path.stem
    high, middle, fine = [int(x) for x in name.split('-')[1:4]]
    return fine-1

  def create_meta_for_wav(self, wav_path):
    if isinstance(wav_path, str):
      wav_path = Path(wav_path)

    # 파일 이름 형태가 1-1-1-1.wav 이런 식이라고 가정할 때
    category_idx = self.get_category_idx(wav_path)
    
    # try:
    #   mp3_dur = self.check_mp3_format(wav_path)
    # except:
    #   print(f"Error occured while reading mp3 of {wav_path}")


    if self.check_name_is_wrong(wav_path):
      # print(f"Name is wrong for {wav_path}")
      self.error_list.append(wav_path, "Category is wrong")
    meta = copy(self.vocab[category_idx])
    meta['녹음 방식'] = self.get_recording_type(str(wav_path))
    meta['파일 이름'] = wav_path.name

    ob = sf.SoundFile(wav_path)
    # if abs(mp3_dur - ob.frames / ob.samplerate) > 0.2:
    #   print(f"Duration of MP3 and Wav is different: {ob.frames / ob.samplerate}, {mp3_dur}")

    meta['샘플링 레이트'] = ob.samplerate
    meta['채널 수'] = ob.channels
    meta['Bit_depth'] = int(ob.subtype.split('_')[1])
    if meta['Bit_depth'] != 24:
      # print(f"Bit-depth of {wav_path} is {meta['Bit_depth']}")
      self.add_error(wav_path, f"Bit-depth is {meta['Bit_depth']}")
    if meta['채널 수'] != 2:
      print(f"Num Channels of {wav_path} is {meta['채널 수']}")
      self.add_error(wav_path, f"Num channels is {meta['채널 수']}")
    if meta['샘플링 레이트'] != 96000:
      print(f"Sampling rate of {wav_path} is {meta['샘플링 레이트']}")
      self.add_error(wav_path, f"Sampling rate is {meta['샘플링 레이트']}")

    meta['길이'] = ob.frames / ob.samplerate # second 
    if True: #if it is field recording
      docx_path = wav_path.parent.parent / 'metadata' / wav_path.with_suffix('.docx').name
      excel_path = docx_path.with_suffix('.xlsx')
      if excel_path.exists():
        detailed_meta = pd.read_excel(excel_path)
        if meta['녹음 방식'] == "필드 레코딩":
          meta["필드 레코딩 메타"] = detailed_meta
        print(excel_path)
        meta["제목"] = detailed_meta.pop("제목")
      elif docx_path.exists():
        try:
          detailed_meta = self.read_table_from_docx(docx_path)
          pd.DataFrame(detailed_meta, index=['']).T.to_excel(docx_path.with_suffix('.xlsx'))
          if meta['녹음 방식'] == "필드 레코딩":
            meta["필드 레코딩 메타"] = detailed_meta
          meta["제목"] = detailed_meta.pop("제목")
        except Exception as e:
          self.add_error(wav_path, f"Error occured while handling the corresponding docx")
      else:
        self.add_error(wav_path, "Meta docx does not exist")
    # self.get_audio_features(ob)
    return meta

  def read_table_from_docx(self, docx_path):
    document = Document(docx_path)
    table = document.tables[0]
    table_dict = {row.cells[0].text:row.cells[1].text for row in table.rows[1:]}
    return table_dict


  def get_audio_features(self, soundfile:sf.SoundFile):
    y = soundfile.read()
    y = y.mean(1)
    spec_centroid = librosa.feature.spectral_centroid(y = y, sr=soundfile.samplerate)
    print(spec_centroid)

    return

meta_creator = MetaCreator('vocab.json')
# meta_creator.create_meta_for_wav(dataset.wav_list[0])
entire_meta = [meta_creator.create_meta_for_wav(wav) for wav in tqdm(dataset.wav_list)]
# Out:
#   0%|          | 0/497 [00:00<?, ?it/s]
# /home/teo/label-studio_files/nia_dataset/__DATA_v4/01/metadata/fs-2-4-78-1-어상진.xlsx
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '제목'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/teo/userdata/nia-sound-event/create_metadata.ipynb 셀 4 in <module>
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=127'>128</a> meta_creator = MetaCreator('vocab.json')
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=128'>129</a> # meta_creator.create_meta_for_wav(dataset.wav_list[0])
# --> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=129'>130</a> entire_meta = [meta_creator.create_meta_for_wav(wav) for wav in tqdm(dataset.wav_list)]
#
# /home/teo/userdata/nia-sound-event/create_metadata.ipynb 셀 4 in <listcomp>(.0)
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=127'>128</a> meta_creator = MetaCreator('vocab.json')
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=128'>129</a> # meta_creator.create_meta_for_wav(dataset.wav_list[0])
# --> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=129'>130</a> entire_meta = [meta_creator.create_meta_for_wav(wav) for wav in tqdm(dataset.wav_list)]
#
# /home/teo/userdata/nia-sound-event/create_metadata.ipynb 셀 4 in MetaCreator.create_meta_for_wav(self, wav_path)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=95'>96</a>     meta["필드 레코딩 메타"] = detailed_meta
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=96'>97</a>   print(excel_path)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=97'>98</a>   meta["제목"] = detailed_meta.pop("제목")
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=98'>99</a> elif docx_path.exists():
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=99'>100</a>   try:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5226, in DataFrame.pop(self, item)
#    5185 def pop(self, item: Hashable) -> Series:
#    5186     """
#    5187     Return item and drop from frame. Raise KeyError if not found.
#    5188
#    (...)
#    5224     3  monkey        NaN
#    5225     """
# -> 5226     return super().pop(item=item)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:870, in NDFrame.pop(self, item)
#     869 def pop(self, item: Hashable) -> Series | Any:
# --> 870     result = self[item]
#     871     del self[item]
#     873     return result
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: '제목'

# %%
meta_creator.error_list
# Out:
# [{'file': 'fs-2-4-75-1-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-75-1-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-75-1-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-75-1-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-75-2-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-75-2-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-75-2-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-75-2-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-75-3-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-75-3-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-75-3-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-75-3-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-1-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-78-1-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-1-송화영.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-1-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-78-1-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-1-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-2-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-78-2-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-2-송화영.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-2-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-78-2-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-2-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-3-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-78-3-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-3-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-78-3-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-78-3-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-79-1-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-86-1-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-86-1-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-86-1-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-86-1-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-86-2-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-86-2-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-86-2-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-86-2-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-86-3-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-86-3-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-86-3-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-86-3-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-87-1-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-87-1-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-87-1-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-87-1-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-87-2-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-87-2-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-87-2-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-87-2-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-87-3-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'fs-2-4-87-3-김준형.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-87-3-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'fs-2-4-87-3-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-1-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-1-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-1-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-1-민건욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-1-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-1-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-13-박채원.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-14-박채원.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-15-박채원.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-2-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-2-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-2-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-2-민건욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-2-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-2-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-2-허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-3-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-3-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-3-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-3-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-3-민건욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-3-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-1-3-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-4-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-4-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-1-5-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-1-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-1-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-1-김영운.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-1-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-1-윤상빈.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-1-이주용.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-1-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-1-허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-10-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-11-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-12-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-13-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-2-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-2-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-2-김영운.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-2-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-2-윤상빈.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-2-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-2-허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-3 허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-3-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-3-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-3-김영운.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-3-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-3-윤상빈.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-3-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-4-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-4-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-5-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-8-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-2-9-김민규.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-1-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-1-김영운.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-1-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-1-민건욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-1-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-3-1-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-1-한은광.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-1-허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-2-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-2-김영운.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-2-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-2-민건욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-2-윤상빈.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-2-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-2-한은광.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-2-허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-3-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-3-김영운.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-3-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-3-민건욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-3-윤상빈.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-3-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-3-한은광.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-3-허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-3-4-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-1-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-1-김영운.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-1-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-1-민건욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-1-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-1-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': 'r-1-1-4-1-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-1-허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-10-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-11-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-12-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-13-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-14-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-2-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-2-김영운.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-2-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-2-민건욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-2-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-2-윤상빈.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-2-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-2-허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-3-김시온.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-3-김영운.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-3-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-3-민건욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-3-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-3-윤상빈.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-3-정욱.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-3-허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-4-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-5-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-6-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-7-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-8-백승렬.wav', 'error': 'Meta docx does not exist'},
#  {'file': 'r-1-1-4-9-백승렬.wav', 'error': 'Meta docx does not exist'}]

# %%
import numpy as np

class AudioFeatureExtractor:
  def __init__(self):
    pass 

  def get_audio_features(self, y:np.ndarray, sr:int):
    spec = self.get_spec(y, sr)
    
    spec_centroid = self.get_mean_and_std_of_audio_feature(spec, sr, librosa.feature.spectral_centroid, 'spectral centroid')
    
    spec_centroid.update(self.get_mean_and_std_of_audio_feature(spec, sr, librosa.feature.spectral_bandwidth, 'spectral bandwidth'))
    spec_centroid.update(self.get_mean_and_std_of_audio_feature(spec, sr, librosa.feature.spectral_contrast, 'spectral contrast'))
    spec_centroid.update(self.get_mean_and_std_of_audio_feature(spec, sr, librosa.feature.spectral_rolloff, 'spectral roll off'))
    spec_centroid.update(self.get_mean_and_std_of_audio_feature_wo_sr(y, librosa.feature.spectral_flatness, 'spectral flatness'))
    spec_centroid.update(self.get_mean_and_std_of_audio_feature_wo_sr(y, librosa.feature.zero_crossing_rate, 'zero crossing rate'))
    spec_centroid.update(self.get_mean_and_std_of_audio_feature_wo_sr(y, librosa.feature.rms, 'rms'))

    return spec_centroid
  
  def get_spec(self, y, sr):
    return np.abs(librosa.stft(y))
  
  def get_mean_and_std_of_audio_feature(self, y, sr, audio_feature, audio_feature_name:str):
    audio_features = audio_feature(S = y, sr = sr)
    return {f'{audio_feature_name} mean': np.mean(audio_features) , f'{audio_feature_name} std':np.std(audio_features) }
  
  def get_mean_and_std_of_audio_feature_wo_sr(self, y, audio_feature, audio_feature_name:str):
    audio_features = audio_feature(y = y)
    return {f'{audio_feature_name} mean': np.mean(audio_features) , f'{audio_feature_name} std':np.std(audio_features) }

  def read_soundfile(self, soundfile:sf.SoundFile):
    y = soundfile.read()
    y = y.mean(1)
    return y, soundfile.samplerate

  def __call__(self, soundfile:sf.SoundFile):
    y, sr = self.read_soundfile(soundfile)
    return self.get_audio_features(y, sr)

extractor = AudioFeatureExtractor()
ob = sf.SoundFile(dataset.wav_list[290])

# extractor(ob)

# %%
example_meta = entire_meta[290]
example_meta['오디오 음향 특성'] = extractor(ob)

# %%
with open("example_meta.json", 'w') as f:
  json.dump(example_meta, f, ensure_ascii=False)
# example_meta

# %%
import pandas as pd
pd.DataFrame([(x['소분류'], x['녹음 방식'], x['파일 이름'], x['길이']) for x in entire_meta]).to_csv('length.csv')

# %%
len(dataset.wav_list)
# Out:
# 475

# %%
[error['file'] for error in meta_creator.error_list if error['error'] == 'Error occured while handling the corresponding docx']
# Out:
# ['2-4-78-1-윤정현.wav',
#  '2-4-78-1-조현진.wav',
#  '2-4-78-2-윤정현.wav',
#  '2-4-78-2-조현진.wav',
#  '2-4-78-3-윤정현.wav',
#  '2-4-78-3-조현진.wav',
#  '2-4-79-1-윤정현.wav',
#  '2-4-79-1-조현진.wav',
#  '2-4-79-2-윤정현.wav',
#  '2-4-79-2-조현진.wav',
#  '2-4-79-3-윤정현.wav',
#  '2-4-79-3-조현진.wav',
#  '2-4-79-4-윤정현.wav',
#  '2-4-79-4-조현진.wav',
#  '2-4-80-1-윤정현.wav',
#  '2-4-80-1-조현진.wav',
#  '2-4-80-2-윤정현.wav',
#  '2-4-80-2-조현진.wav',
#  '2-4-80-3-윤정현.wav',
#  '2-4-80-3-조현진.wav',
#  '2-4-92-1-윤정현.wav',
#  '2-4-92-1-조현진.wav',
#  '2-4-92-2-윤정현.wav',
#  '2-4-92-2-조현진.wav',
#  '2-4-92-3-윤정현.wav',
#  '2-4-92-3-조현진.wav',
#  '2-4-92-4-윤정현.wav',
#  '1-1-1-1-김시온.wav',
#  '1-1-1-13-박채원.wav',
#  '1-1-1-14-박채원.wav',
#  '1-1-1-15-박채원.wav',
#  '1-1-1-2-허진만.wav',
#  '1-1-1-3-김민규.wav',
#  '1-1-1-3-김시온.wav',
#  '1-1-1-4-김민규.wav',
#  '1-1-2-1-김민규.wav',
#  '1-1-2-1-김시온.wav',
#  '1-1-2-1-김영운.wav',
#  '1-1-2-1-윤상빈.wav',
#  '1-1-2-1-이주용.wav',
#  '1-1-2-1-정욱.wav',
#  '1-1-2-1-허진만.wav',
#  '1-1-2-10-김민규.wav',
#  '1-1-2-11-김민규.wav',
#  '1-1-2-12-김민규.wav',
#  '1-1-2-13-김민규.wav',
#  '1-1-2-2-김민규.wav',
#  '1-1-2-2-김시온.wav',
#  '1-1-2-2-김영운.wav',
#  '1-1-2-2-윤상빈.wav',
#  '1-1-2-2-정욱.wav',
#  '1-1-2-2-허진만.wav',
#  '1-1-2-3-김민규.wav',
#  '1-1-2-3-김시온.wav',
#  '1-1-2-3-김영운.wav',
#  '1-1-2-3-윤상빈.wav',
#  '1-1-2-3-정욱.wav',
#  '1-1-2-4-김민규.wav',
#  '1-1-2-4-정욱.wav',
#  '1-1-2-5-김민규.wav',
#  '1-1-2-8-김민규.wav',
#  '1-1-2-9-김민규.wav',
#  '1-1-3-1-김시온.wav',
#  '1-1-3-1-김영운.wav',
#  '1-1-3-1-민건욱.wav',
#  '1-1-3-1-정욱.wav',
#  '1-1-3-1-한은광.wav',
#  '1-1-3-1-허진만.wav',
#  '1-1-3-2-김시온.wav',
#  '1-1-3-2-김영운.wav',
#  '1-1-3-2-민건욱.wav',
#  '1-1-3-2-윤상빈.wav',
#  '1-1-3-2-정욱.wav',
#  '1-1-3-2-한은광.wav',
#  '1-1-3-2-허진만.wav',
#  '1-1-3-3-김시온.wav',
#  '1-1-3-3-김영운.wav',
#  '1-1-3-3-민건욱.wav',
#  '1-1-3-3-윤상빈.wav',
#  '1-1-3-3-정욱.wav',
#  '1-1-3-3-한은광.wav',
#  '1-1-3-3-허진만.wav',
#  '1-1-3-4-정욱.wav',
#  '1-1-4-1-김시온.wav',
#  '1-1-4-1-김영운.wav',
#  '1-1-4-1-민건욱.wav',
#  '1-1-4-1-백승렬.wav',
#  '1-1-4-1-정욱.wav',
#  '1-1-4-1-허진만.wav',
#  '1-1-4-10-백승렬.wav',
#  '1-1-4-11-백승렬.wav',
#  '1-1-4-12-백승렬.wav',
#  '1-1-4-13-백승렬.wav',
#  '1-1-4-14-백승렬.wav',
#  '1-1-4-2-김시온.wav',
#  '1-1-4-2-김영운.wav',
#  '1-1-4-2-민건욱.wav',
#  '1-1-4-2-백승렬.wav',
#  '1-1-4-2-윤상빈.wav',
#  '1-1-4-2-정욱.wav',
#  '1-1-4-2-허진만.wav',
#  '1-1-4-3-김시온.wav',
#  '1-1-4-3-김영운.wav',
#  '1-1-4-3-민건욱.wav',
#  '1-1-4-3-백승렬.wav',
#  '1-1-4-3-윤상빈.wav',
#  '1-1-4-3-정욱.wav',
#  '1-1-4-3-허진만.wav',
#  '1-1-4-4-백승렬.wav',
#  '1-1-4-5-백승렬.wav',
#  '1-1-4-6-백승렬.wav',
#  '1-1-4-7-백승렬.wav',
#  '1-1-4-8-백승렬.wav',
#  '1-1-4-9-백승렬.wav']

# %%
meta_creator.error_list
# Out:
# [{'file': '2-4-78-1-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-78-1-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-1-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-2-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-78-2-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-2-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-3-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-78-3-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-3-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-79-1-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-79-1-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-79-1-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-79-2-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-79-2-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-79-2-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-79-3-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-79-3-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-79-3-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-79-4-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-79-4-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-80-1-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-80-1-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-80-1-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-80-2-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-80-2-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-80-2-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-80-3-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-80-3-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-80-3-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-92-1-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-92-1-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-92-1-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-92-2-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-92-2-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-92-2-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-92-3-김규동.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-92-3-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-92-3-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-92-3-조현진.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-92-4-어상진.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-92-4-윤정현.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-1-1-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-1-1-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-1-13-박채원.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-1-14-박채원.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-1-15-박채원.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-1-2-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-1-2-허진만.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-1-3-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-1-3-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-1-3-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-1-4-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-1-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-1-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-1-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-1-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-2-1-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-1-이주용.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-1-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-1-허진만.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-10-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-11-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-12-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-13-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-2-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-2-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-2-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-2-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-2-2-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-2-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-2-허진만.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-3 허진만.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-2-3-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-3-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-3-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-3-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-2-3-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-3-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-4-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-4-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-5-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-8-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-2-9-김민규.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-1-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-1-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-1-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-3-1-민건욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-1-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-1-한은광.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-1-허진만.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-2-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-2-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-2-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-3-2-민건욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-2-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-2-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-2-한은광.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-2-허진만.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-3-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-3-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-3-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-3-3-민건욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-3-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-3-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-3-한은광.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-3-허진만.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-3-4-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-1-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-1-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-1-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-4-1-민건욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-1-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-1-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-1-허진만.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-10-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-11-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-12-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-13-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-14-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-2-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-2-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-2-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-4-2-민건욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-2-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-2-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-2-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-2-허진만.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-3-김시온.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-3-김영운.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-3-김영은.wav', 'error': 'Meta docx does not exist'},
#  {'file': '1-1-4-3-민건욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-3-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-3-윤상빈.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-3-정욱.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-3-허진만.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-4-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-5-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-6-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-7-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-8-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '1-1-4-9-백승렬.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-75-1-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-75-1-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-75-1-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-75-1-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-75-2-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-75-2-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-75-2-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-75-2-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-75-3-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-75-3-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-75-3-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-75-3-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-1-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-78-1-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-78-1-송화영.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-1-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-1-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-2-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-78-2-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-78-2-송화영.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-2-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-2-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-3-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-78-3-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-78-3-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-78-3-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-86-1-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-86-1-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-86-1-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-86-1-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-86-2-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-86-2-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-86-2-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-86-2-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-86-3-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-86-3-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-86-3-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-86-3-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-87-1-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-87-1-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-87-1-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-87-1-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-87-2-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-87-2-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-87-2-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-87-2-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-87-3-김양우.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-87-3-김준형.wav', 'error': 'Meta docx does not exist'},
#  {'file': '2-4-87-3-이동화.wav',
#   'error': 'Error occured while handling the corresponding docx'},
#  {'file': '2-4-87-3-장완석.wav',
#   'error': 'Error occured while handling the corresponding docx'}]

# %%
entire_meta[290]
# Out:
# {'소분류': '병원',
#  '소분류_번호': 2,
#  '중분류': '실제 공간(앰비언스)',
#  '대분류': '공간',
#  '중분류_번호': 1,
#  '대분류_번호': 1,
#  '녹음 방식': '필드 레코딩',
#  '파일 이름': '1-1-2-2-전소형.wav',
#  '샘플링 레이트': 96000,
#  '채널 수': 2,
#  'Bit_depth': 24,
#  '길이': 130.0,
#  '필드 레코딩 메타': {'분류 번호': '1-1-2',
#   '녹음자 성명': '전소형',
#   '녹음 연/월/일': '2022.07.13',
#   '사용 기자재': 'Zoom H6 레코더, 헤드셋',
#   '오디오 포맷': '스테레오 - wav (96k, 24bit) / mp3',
#   '오디오 길이': '130초',
#   '녹음 장소': '서울시 서초구 반포동 505',
#   '녹음 지점': '37.50117, 127.00459',
#   '음원으로부터의 거리': '0 미터',
#   '기후 등 환경 조건': '대리석 구조물과 습한 날씨 등으로 인한 공간감.',
#   '소리의 강도': '-22 dB',
#   '보안 이슈': '없음',
#   '기타 특이사항': '*비 때문에 신발 마찰음 다수.'},
#  '제목': '서울성모병원 1층 엘리베이터 앞'}

# %%
for meta in entire_meta:
  if '필드 레코딩 메타' in meta:
    print(meta['필드 레코딩 메타']['소리의 강도'])
# Out:
# -30 dB
# -36 dB~-24db
# -36 dB
# -30 dB
# -36dB~-24db
# -48 dB
# -36~-20 dB
# -24dB
# -30 dB
# -30 dB
# -33 dB
# -30 dB
# -33 dB
# -30 dB
# -30 dB
# -33 dB
# -20 dB
# -20 dB
# -20 dB
# -20 dB
# -20 dB
# -27 dB
# -20 dB
# -20 dB
# -20 dB
# -27 dB
# -24 dB
# -27 dB
# -27 dB
# -30 dB
# -30 dB
# -24 dB
# -30 dB
# -20 dB
# -44.4 db
# -25.6 db
# -25.6 db
# -25.6 db
# -25.6 db
# -25.6 db
# -25.6 db
# -44.4 db
# -42.7 db
# -35.2 db
# -25.6 db
# -25.6 db
# -25.6 db
# -25.6 db
# -25.6 db
# -15dBFS
# -5dBFS
# -7dBFS
# -9dBFS
# -9dBFS
# -9dBFS
# -15dBFS
# -14dBFS
# -14dBFS
# -12dBFS
# -15dBFS
# -20dBFS
# -20dBFS
# -5dBFS
# -5dBFS

# %%
test = Document("/home/teo/userdata/nia_dataset/field_recording/5팀 이상화 1주차/metadata/1-2-5-1-김민규.docx")
table = test.tables[0]

for row in table.rows:
  print(row.cells[0].text, '//', row.cells[1].text)
# Out:
# 1차 원시데이터 기록표 //
# 1-2-5-1 // 제목
# 녹음자 성명 // 김민규
# 2022.07.12 // 사용 기자재
# 오디오 포맷 // 스테레오 - wav (96k, 24bit)
# 284초 // 녹음 장소
# 녹음 지점 // 37.482062, 126.942231
# X-Ray 촬영기기로부터 약 1.5미터 // 기후 등 환경 조건
# 소리의 강도 // -30 dB
# 없음 // 기타 특이사항
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/teo/userdata/nia-sound-event/create_metadata.ipynb 셀 7 in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000011vscode-remote?line=1'>2</a> table = test.tables[0]
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000011vscode-remote?line=3'>4</a> for row in table.rows:
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000011vscode-remote?line=4'>5</a>   print(row.cells[0].text, '//', row.cells[1].text)
#
# IndexError: tuple index out of range

# %%
meta_creator.read_table_from_docx("/home/teo/userdata/nia_dataset/field_recording/4팀 김양우 1주차/metadata/1-1-3-1-한은광.docx")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/teo/userdata/nia-sound-event/create_metadata.ipynb 셀 8 in <module>
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000015vscode-remote?line=0'>1</a> meta_creator.read_table_from_docx("/home/teo/userdata/nia_dataset/field_recording/4팀 김양우 1주차/metadata/1-1-3-1-한은광.docx")
#
# /home/teo/userdata/nia-sound-event/create_metadata.ipynb 셀 8 in MetaCreator.read_table_from_docx(self, docx_path)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000015vscode-remote?line=65'>66</a> document = Document(docx_path)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000015vscode-remote?line=66'>67</a> table = document.tables[0]
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000015vscode-remote?line=67'>68</a> table_dict = {row.cells[0].text:row.cells[1].text for row in table.rows[1:]}
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000015vscode-remote?line=69'>70</a> return table_dict
#
# /home/teo/userdata/nia-sound-event/create_metadata.ipynb 셀 8 in <dictcomp>(.0)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000015vscode-remote?line=65'>66</a> document = Document(docx_path)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000015vscode-remote?line=66'>67</a> table = document.tables[0]
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000015vscode-remote?line=67'>68</a> table_dict = {row.cells[0].text:row.cells[1].text for row in table.rows[1:]}
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224d414c6572227d/home/teo/userdata/nia-sound-event/create_metadata.ipynb#ch0000015vscode-remote?line=69'>70</a> return table_dict
#
# IndexError: tuple index out of range

# %%
Path("/home/teo/userdata/nia_dataset/field_recording/5팀 이상화 1주차/metadata/1-2-7-6-백승렬.docx").exists()
# Out:
# True

# %%
table = meta_creator.read_table_from_docx('1-1-1-1-송영재.docx')
table
# Out:
# {'분류 번호': '1-1-1',
#  '제목': '로얄호텔 서울 2층',
#  '녹음자 성명': '송영재',
#  '녹음 연/월/일': '2022.7.16',
#  '사용 기자재': 'Zoom H6 레코더, 이어폰',
#  '오디오 포맷': '스테레오 - wav (96k, 24bit) / mp3',
#  '오디오 길이': '180초',
#  '녹음 장소': '서울 중구 명동길 61 로얄호텔 서울',
#  '녹음 지점': '37.564296, 126.985583',
#  '음원으로부터의 거리': '약 3m',
#  '기후 등 환경 조건': '실내',
#  '소리의 강도': '-30 dB',
#  '보안 이슈': '없음',
#  '기타 특이사항': '-'}

# %%
import pandas as pd
pd.DataFrame(table, index=['']).T.to_excel('1-1-1-1-송영재.xlsx')

# %%
pd.read_excel('/home/teo/label-studio_files/nia_dataset/__DATA_v4/01/metadata/fs-2-4-78-1-어상진.xlsx')
# Out:
#    1차 원시데이터 기록표 (폴리/합성)  Unnamed: 1                  Unnamed: 2  \
# 0                    번호          구분                          내용
# 1                     1       분류 표기                      1-3-24
# 2                     2  상황 묘사(제목)                  선풍기 돌아가는 소리
# 3                     3     합성 방식 1                         NaN
# 4                     4   제작시 사용 개체                         NaN
# 5                     5     합성 방식 2  신디사이저 및 샘플, 이펙터를 활용한 합성 음원
# 6                     6   제작시 사용 개체               Logic Pro DAW
# 7                     8      오디오 포맷      wav (스테레오, 96k, 24bit)
# 8                     9   녹음/제작자 성명                         어상진
# 9                    10    제작 연/월/일                  2022.07.08
# 10                   11       보안 이슈                          없음
# 11                   12     기타 특이사항                         NaN
#
#                               Unnamed: 3
# 0                                     비고
# 1                              분류 기준표 참고
# 2                             구체적인 상황 기재
# 3                      폴리 사운드 미활용시 공란 기재
# 4                 폴리 방식 활용시 구체적 수음 방식 기재
# 5                      합성 사운드 미활용시 공란 기재
# 6                              가급적 상세 기재
# 7                                    NaN
# 8                                    NaN
# 9    입력 시 2022.07.28 (O) / 2022.7.28 (X)
# 10                        불법 샘플 소스 사용 금지
# 11                            기타 특이사항 기재

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 8.8 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10

# %%
meta_creator.vocab['idx2title']
# Out:
# ['호텔',
#  '병원',
#  '놀이공원',
#  '상업 몰',
#  '공항',
#  '전시장',
#  '백화점',
#  '마트',
#  '재래시장',
#  '지하상가',
#  '주차장',
#  '버스 정류장',
#  '버스 터미널',
#  '지하철역',
#  '기차역',
#  '레스토랑/음식점',
#  '카페',
#  '술집',
#  '영화관',
#  '헬스장',
#  '상업지역',
#  '도서관',
#  '공원',
#  '관공서',
#  '사무실',
#  '종교 시설',
#  '수영장',
#  '경기장 (실내)',
#  '경기장 (실외)',
#  '교외 거주지역',
#  '아파트 단지',
#  '가정 실내',
#  '룸톤',
#  '도심 지역',
#  '교통 소리',
#  '군중 소리',
#  '동물원',
#  '학교',
#  '창고',
#  '공장',
#  '항구',
#  '숲',
#  '드넓은 초원',
#  '동굴',
#  '바닷가',
#  '강/계곡/하천/냇가 등',
#  '호숫가',
#  '폭포',
#  '가상 업무 공간',
#  '고대 문명 도시',
#  '해저 도시',
#  '하늘 도시',
#  '판타지 중세 성',
#  '서부 총잡이 도시',
#  '공상과학/사이버펑크 미래도시',
#  '무한한 터널',
#  '타임머신',
#  '워프',
#  '레이싱',
#  '기계 도시',
#  '우주 도시',
#  '화산지대',
#  '실험실',
#  '우주선 복도',
#  '우주 정거장',
#  '서버실',
#  '상황실',
#  '신전',
#  '광산',
#  '외계 도시',
#  '지하 도시',
#  '우주 공간 시나리오',
#  '우주선 탑승 시나리오',
#  '자연 재해 시나리오',
#  '인공 전쟁/전투 시나리오',
#  '가상 전쟁/전투 시나리오',
#  '위급 상황 관련 시나리오',
#  '건축 관련 소리 시나리오',
#  '음식 만드는 시나리오',
#  '실내 청소 시나리오',
#  '샤워 관련 소리 시나리오',
#  '자전거 탑승 시나리오',
#  '버스 탑승 시나리오',
#  '차량 탑승 시나리오',
#  '오토바이 탑승 시나리오',
#  '비행기 탑승 시나리오',
#  '헬리콥터 탑승 시나리오',
#  '보트 탑승 시나리오',
#  '유람선 탑승 시나리오',
#  '기차 탑승 시나리오',
#  '폭발 관련 소리 시나리오',
#  '구강 발생 소리 시나리오',
#  '손을 이용한 소리 시나리오',
#  '발을 이용한 소리 시나리오',
#  '그 외 신체 소리 시나리오',
#  '동물/곤충 소리 시나리오',
#  '바람 관련 소리 시나리오',
#  '비 관련 소리 시나리오',
#  '눈 관련 소리 시나리오',
#  '천둥번개/우뢰 관련 소리 시나리오',
#  '유리 관련 소리 시나리오',
#  '호러/SF 장르 관련 소리 1 - 자르는 소리',
#  '호러/SF 장르 관련 소리 2 - 부러지는 소리',
#  '호러/SF 장르 관련 소리 3 - 괴물 소리',
#  '호러/SF 장르 관련 소리 4 - 비명 소리',
#  '호러/SF 장르 관련 소리 5 - 음산한 소리',
#  '카메라 촬영 관련 소리 시나리오',
#  '쇠사슬 행위 관련 소리 시나리오',
#  '제품 켜는 소리 시나리오',
#  '엘리베이터 탑승 관련 시나리오',
#  '문 관련 소리 시나리오',
#  '시계 관련 소리 시나리오',
#  '액체 관련 소리 시나리오',
#  '컴퓨터 관련 소리 시나리오',
#  '오래된 전화기 관련 소리 시나리오',
#  '스마트폰 관련 소리 시나리오',
#  '라디오 관련 소리 시나리오',
#  '텔레비전 관련 소리 시나리오',
#  '타자기 관련 소리 시나리오',
#  '로봇 관련 소리 시나리오',
#  '레이저 관련 소리 시나리오']

# %%
mediainfo("/home/teo/userdata/nia_dataset/field_recording/5팀 이상화 1주차/mp3/1-2-7-6-백승렬.mp3")
# Out:
# {'index': '0',
#  'codec_name': 'mp3',
#  'codec_long_name': 'MP3 (MPEG audio layer 3)',
#  'profile': 'unknown',
#  'codec_type': 'audio',
#  'codec_time_base': '1/48000',
#  'codec_tag_string': '[0][0][0][0]',
#  'codec_tag': '0x0000',
#  'sample_fmt': 'fltp',
#  'sample_rate': '48000',
#  'channels': '2',
#  'channel_layout': 'stereo',
#  'bits_per_sample': '0',
#  'id': 'N/A',
#  'r_frame_rate': '0/0',
#  'avg_frame_rate': '0/0',
#  'time_base': '1/14112000',
#  'start_pts': '324870',
#  'start_time': '0.023021',
#  'duration_ts': '2693246976',
#  'duration': '190.848000',
#  'bit_rate': '320132',
#  'max_bit_rate': 'N/A',
#  'bits_per_raw_sample': 'N/A',
#  'nb_frames': 'N/A',
#  'nb_read_frames': 'N/A',
#  'nb_read_packets': 'N/A',
#  'DISPOSITION': {'default': '0',
#   'dub': '0',
#   'original': '0',
#   'comment': '0',
#   'lyrics': '0',
#   'karaoke': '0',
#   'forced': '0',
#   'hearing_impaired': '0',
#   'visual_impaired': '0',
#   'clean_effects': '0',
#   'attached_pic': '0',
#   'timed_thumbnails': '0'},
#  'TAG': {'encoder': 'LAME3.100', 'TYER': '2022-07-12'},
#  'filename': '/home/teo/userdata/nia_dataset/field_recording/5팀 이상화 1주차/mp3/1-2-7-6-백승렬.mp3',
#  'nb_streams': '1',
#  'nb_programs': '0',
#  'format_name': 'mp3',
#  'format_long_name': 'MP2/3 (MPEG audio layer 2/3)',
#  'size': '7637088',
#  'probe_score': '51'}

# %%
import docx

def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

test = getText('1-1-1-1-송영재.docx')

# %%
from docx.api import Document

# Load the first table from your document. In your example file,
# there is only one table, so I just grab the first one.
document = Document('1-1-1-1-송영재.docx')
table = document.tables[0]

# %%
data = []

keys = None
for i, row in enumerate(table.rows):
    text = (cell.text for cell in row.cells)

    # Establish the mapping based on the first row
    # headers; these will become the keys of our dictionary
    if i == 0:
        keys = tuple(text)
        continue

    # Construct a dictionary for this row, mapping
    # keys to values for this row
    row_data = dict(zip(keys, text))
    data.append(row_data)
data[0]['']
# Out:
# '1-1-1'

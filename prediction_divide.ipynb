# %%
import json
from pathlib import Path

prediction_path = Path('/home/clay/userdata/nia-sound-event-1/prediction_threshold0.05.json/')
with open(prediction_path, 'r') as f:
  pred = json.load(f)

# %%
pred[0:85]
# Out:
# [{'id': 0,
#   'predictions': [{'id': 1,
#     'result': [{'value': {'start': 6.08,
#        'end': 7.36,
#        'labels': ['Propeller, airscrew'],
#        'score': 0.09633517265319824},
#       'from_name': 'label',
#       'to_name': 'audio',
#       'type': 'labels'},
#      {'value': {'start': 1.42,
#        'end': 6.74,
#        'labels': ['Car'],
#        'score': 0.19347688555717468},
#       'from_name': 'label',
#       'to_name': 'audio',
#       'type': 'labels'},
#      {'value': {'start': 20.16,
#        'end': 21.12,
#        'labels': ['Thunderstorm'],
#        'score': 0.13073204457759857},
#       'from_name': 'label',
#       'to_name': 'audio',
#       'type': 'labels'},
#      {'value': {'start': 14.72,
#        'end': 15.36,
#        'labels': ['Explosion'],
#        'score': 0.05591967701911926},
#       'from_name': 'label',
#       'to_name': 'audio',
#       'type': 'labels'},
#      {'value': {'start': 8.32,
#        'end': 10.24,
# ...
